# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed0barhoomi/final_DATASC/blob/main/last_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import StandardScaler,LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from  sklearn.cluster import KMeans,MiniBatchKMeans,AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score,davies_bouldin_score
import hdbscan
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import plotly.express as px

# %%
data=pd.read_csv("dataset.csv", sep=",")
print(data.columns)
print(data.head())
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
#  16  liveness          114000 non-null  float64
#  17  valence           114000 non-null  float64
#  18  tempo             114000 non-null  float64
#  19  time_signature    114000 non-null  int64
#  20  track_genre       114000 non-null  object
# dtypes: bool(1), float64(9), int64(6), object(5)
# memory usage: 17.5+ MB
# None

# %%
data.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# 25%         0.472000       2.000000     -10.013000       0.000000
# 50%         0.685000       5.000000      -7.004000       1.000000
# 75%         0.854000       8.000000      -5.003000       1.000000
# max         1.000000      11.000000       4.532000       1.000000
#
#          speechiness   acousticness  instrumentalness       liveness  \
# count  114000.000000  114000.000000     114000.000000  114000.000000
# mean        0.084652       0.314910          0.156050       0.213553
# std         0.105732       0.332523          0.309555       0.190378
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.035900       0.016900          0.000000       0.098000
# 50%         0.048900       0.169000          0.000042       0.132000
# 75%         0.084500       0.598000          0.049000       0.273000
# max         0.965000       0.996000          1.000000       1.000000
#
#              valence          tempo  time_signature
# count  114000.000000  114000.000000   114000.000000
# mean        0.474068     122.147837        3.904035
# std         0.259261      29.978197        0.432621
# min         0.000000       0.000000        0.000000
# 25%         0.260000      99.218750        4.000000
# 50%         0.464000     122.017000        4.000000
# 75%         0.683000     140.071000        4.000000
# max         0.995000     243.372000        5.000000

# %%
data.isna().sum()[data.isna().sum()>0]
# Out:
# artists       1
# album_name    1
# track_name    1
# dtype: int64

# %%
data=data.dropna(subset=["artists", "album_name", "track_name"])

print("shape after drop : ",data.shape)
# Out:
# shape after drop :  (113999, 21)

# %%
data = data.drop(columns=["Unnamed: 0"])
print("dupliquate in track id : ",data["track_id"].duplicated().sum())
data=data.drop_duplicates(subset="track_id", keep="first").copy()
print("demention after delete dupliquate music track and unamed col (col of index )",data.shape)
# Out:
# dupliquate in track id :  24259
# demention after delete dupliquate music track and unamed col (col of index ) (89740, 20)

# %%
num_col=[col for col in data.columns if data[col].dtype == "int64" or data[col].dtype == "float64"]
categ_col=[col for col in data.columns if data[col].dtype == "object"]

# %%
three_shold=3
for col in num_col:
   z_score=np.abs(stats.zscore(data[col]))
   ouliers=data[z_score>three_shold]
   print("outliers in col {} : {}".format(col,len(ouliers)/data.shape[0]))
# Out:
# outliers in col popularity : 0.00012257633162469355
# outliers in col duration_ms : 0.008156897704479608
# outliers in col danceability : 0.0017494985513706262
# outliers in col energy : 0.0
# outliers in col key : 0.0
# outliers in col loudness : 0.0219188767550702
# outliers in col mode : 0.0
# outliers in col speechiness : 0.018197013594829507
# outliers in col acousticness : 0.0
# outliers in col instrumentalness : 0.0
# outliers in col liveness : 0.03182527301092044
# outliers in col valence : 0.0
# outliers in col tempo : 0.0020726543347448184
# outliers in col time_signature : 0.011232449297971918

# %%
print("nombre of genre",data["track_genre"].nunique())
print("nobre of artist",data["artists"].nunique())
print("nb of artist par genre : {}".format(round(data["artists"].nunique()/data["track_genre"].nunique(),2)))
# Out:
# nombre of genre 113
# nobre of artist 31437
# nb of artist par genre : 278.2

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(8,5))
sns.histplot(data["popularity"],bins=30,kde=True)
plt.title("Distribution de la popularité des morceaux")
plt.xlabel("Popularité (0-100)")
plt.show()

# %%
genre_popul=data.groupby(["track_genre"])["popularity"].mean().sort_values(ascending=False).head(15)
print(genre_popul)

plt.figure(figsize=(10,6))
sns.barplot(x=genre_popul.values,y=genre_popul.index,hue=genre_popul.index, palette="viridis", legend=False)
plt.xlabel("popularity moy")
# Out:
# track_genre
# k-pop                59.423581
# pop-film             59.096933
# metal                56.422414
# chill                53.738683
# latino               51.788945
# sad                  51.109929
# grunge               50.587007
# indian               49.765348
# anime                48.776884
# emo                  48.500000
# reggaeton            48.270270
# sertanejo            47.860775
# piano                46.608312
# progressive-house    46.537748
# hard-rock            45.744711
# Name: popularity, dtype: float64
# Text(0.5, 0, 'popularity moy')

# %%
artist_count=data["artists"].value_counts()
principale_art=artist_count[artist_count>3].index

top_artist=(data[data["artists"].isin(principale_art)].groupby("artists")["popularity"].mean().sort_values(ascending=False).head(15))
print(top_artist.head())
plt.figure(figsize=(10,6))
sns.barplot(x=top_artist.values,y=top_artist.index,hue=top_artist.index,palette="viridis", legend=False)
plt.xlabel("popularity moy")
plt.show()
# Out:
# artists
# Olivia Rodrigo    87.400000
# Bad Bunny         85.363636
# Lil Nas X         83.200000
# One Direction     83.000000
# Måneskin          82.600000
# Name: popularity, dtype: float64

# %%
audio_feature = ["danceability", "energy", "valence", "acousticness", "speechiness", "tempo"]
top_genre=genre_popul.head(10).index
print(top_genre)
genre_porc=data[data["track_genre"].isin(top_genre)].groupby("track_genre")[audio_feature].mean()
print(genre_porc)
# Out:
# Index(['k-pop', 'pop-film', 'metal', 'chill', 'latino', 'sad', 'grunge',
#        'indian', 'anime', 'emo'],
#       dtype='object', name='track_genre')
#              danceability    energy   valence  acousticness  speechiness  \
# track_genre
# anime            0.537666  0.674229  0.434644      0.267117     0.087429
# chill            0.666423  0.429531  0.408306      0.530572     0.103493
# emo              0.601147  0.667745  0.441194      0.191794     0.112685
# grunge           0.455414  0.804870  0.400566      0.047791     0.061500
# indian           0.585930  0.554673  0.448285      0.511175     0.068742
# k-pop            0.641783  0.682796  0.568961      0.294774     0.085454
# latino           0.755487  0.712343  0.622474      0.208931     0.121987
# metal            0.481177  0.841392  0.424929      0.035705     0.077117
# pop-film         0.591431  0.599897  0.528520      0.450419     0.062044
# sad              0.701801  0.478868  0.439608      0.433583     0.130326
#
#                   tempo
# track_genre
# anime        123.607734
# chill        115.383460
# emo          126.998120
# grunge       129.985355
# indian       115.207430
# k-pop        119.530329
# latino       121.420261
# metal        129.479871
# pop-film     116.953353
# sad          119.359216

# %%
corr_features = ["popularity","danceability","energy","loudness","speechiness",
                  "acousticness","instrumentalness","liveness","valence","tempo"]
plt.figure(figsize=(10,8))
sns.heatmap(data[corr_features].corr(),annot=True,fmt=".2f",cmap="coolwarm",center=0)
plt.show()

# %%
genre_fr = data["track_genre"].value_counts().to_dict()

wc_genre = WordCloud(width=900, height=500,background_color="white",colormap="viridis").generate_from_frequencies(genre_fr)
plt.figure(figsize=(10,10))
plt.imshow(wc_genre)
plt.show()

# %%
artist_fr=data.groupby("artists")["popularity"].mean().sort_values(ascending=False).head(200).to_dict()
wc_artist = WordCloud(width=900, height=500, background_color="white",
                       colormap="viridis").generate_from_frequencies(artist_fr)
plt.figure(figsize=(10,10))
plt.imshow(wc_artist)
plt.show()

# %%
fut_princ=["danceability", "energy", "loudness", "speechiness","acousticness", "instrumentalness", "liveness","valence", "tempo"]
princ_data=data[fut_princ].copy()
print(princ_data.head())
scaler=StandardScaler()
princ_data=scaler.fit_transform(princ_data)
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.676  0.4610    -6.746       0.1430        0.0322
# 1         0.420  0.1660   -17.235       0.0763        0.9240
# 2         0.438  0.3590    -9.734       0.0557        0.2100
# 3         0.266  0.0596   -18.515       0.0363        0.9050
# 4         0.618  0.4430    -9.681       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000001    0.3580    0.715   87.917
# 1          0.000006    0.1010    0.267   77.489
# 2          0.000000    0.1170    0.120   76.332
# 3          0.000071    0.1320    0.143  181.740
# 4          0.000000    0.0829    0.167  119.949

# %%
inertie=[]
for k in range(2,13):
    km=KMeans(n_clusters=k,random_state=42, n_init=10)
    km.fit(princ_data)
    inertie.append(km.inertia_)
print(inertie)
# Out:
# [632735.1509039766, 561695.8865977888, 505597.7698733773, 455891.0995550689, 414345.85700589395, 377050.4746950659, 356486.1119378417, 337943.5946542007, 324164.5503731877, 312026.39648269047, 302257.5723202528]

# %%
plt.figure(figsize=(9,5))
plt.plot(list(range(2,13)), inertie, marker="o")
plt.xlabel("Nombre de clusters ")
plt.ylabel("Inertie")
plt.show()

# %%
part_indx = np.random.RandomState(42).choice(len(princ_data), size=5000, replace=False)
part_data = princ_data[part_indx]
print(princ_data.shape)
print(part_data.shape)
# Out:
# (89740, 9)
# (5000, 9)

# %%
sil_scores = []
DVB=[]
for k in range(2,13):
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    pred = km.fit_predict(part_data)
    sil_scores.append(silhouette_score(part_data, pred))
    DVB.append(davies_bouldin_score(part_data, pred))
plt.figure(figsize=(8,10))
plt.plot(list(range(2,13)), sil_scores, marker="o", color="orange")
plt.plot(list(range(2,13)), DVB, marker="o", color="red")
plt.xlabel("Nb de clusters ")
plt.ylabel("Score")
plt.title("silhoute score par cluster kmeans")
plt.show()

# %%
print("silhoutte de k=8 :",sil_scores[6])
print("DVB de k=8 : ",DVB[6])
# Out:
# silhoutte de k=8 : 0.1937788175975174
# DVB de k=8 :  1.3816100141547218

# %%
sil_scores = []
DVB=[]
for k in range(2,13):
    km = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=500)
    pred = km.fit_predict(part_data)
    sil_scores.append(silhouette_score(part_data, pred))
    DVB.append(davies_bouldin_score(part_data, pred))
plt.figure(figsize=(8,8))
plt.plot(list(range(2,13)), sil_scores, marker="o", color="orange")
plt.plot(list(range(2,13)), DVB, marker="o", color="red")
plt.xlabel("Nb de clusters ")
plt.ylabel("Score")
plt.title("silhoute score par cluster MINI_B_kmeans")
plt.show()

# %%
print("silhoutte de k=8 :", sil_scores[6])
print("DVB de k=8 : ", DVB[6])
# Out:
# silhoutte de k=8 : 0.1460833245383657
# DVB de k=8 :  1.5943200341048107

# %%
sil_scores = []
DVB=[]
for k in range(2,13):
    Gm = GaussianMixture( n_components=k,covariance_type='full',random_state=42)
    pred = Gm.fit_predict(part_data)
    sil_scores.append(silhouette_score(part_data, pred))
    DVB.append(davies_bouldin_score(part_data, pred))

plt.figure(figsize=(8,5))
plt.plot(list(range(2,13)), sil_scores, marker="o", color="orange")
plt.plot(list(range(2,13)), DVB, marker="o", color="red")

plt.xlabel("Nb de clusters ")
plt.ylabel("Score")
plt.title("silhoute score par cluster GaussianMixture")
plt.show()

# %%
print("silhoutte de k=8 :",sil_scores[6])
print("DVB de k=8 : ",DVB[6])
# Out:
# silhoutte de k=8 : -0.02599248781951967
# DVB de k=8 :  5.298717029507853

# %%
sil_scores = []
DVB=[]
for k in range(2,13):
    agg = AgglomerativeClustering(n_clusters=k, linkage='average')
    pred = agg.fit_predict(part_data)
    sil_scores.append(silhouette_score(part_data, pred))
    DVB.append(davies_bouldin_score(part_data, pred))
plt.figure(figsize=(8,8))
plt.plot(list(range(2,13)), sil_scores, marker="o", color="orange")
plt.plot(list(range(2,13)),DVB, marker="o", color="red")
plt.xlabel("Nb de clusters ")
plt.ylabel("Score")
plt.title("silhoute score par cluster AgglomerativeClustering")
plt.show()

# %%
print("silhoutte de k=8 :",sil_scores[4])
print("DVB de k=8 : ",DVB[4])
# Out:
# silhoutte de k=8 : 0.32340898400811807
# DVB de k=8 :  0.8256718873092913

# %%
sil_scores = []
DVB=[]
model = hdbscan.HDBSCAN(min_cluster_size=50, min_samples=10)
pred = model.fit_predict(part_data)
sil_scores.append(silhouette_score(part_data, pred))
DVB.append(davies_bouldin_score(part_data, pred))
print("silhoutte de k=8 :",sil_scores[0])
print("DVB de k=8 : ",DVB[0])
# Out:
# silhoutte de k=8 : 0.12757594444732515
# DVB de k=8 :  2.7642467571334213

# %%
# k=8 is the best nbr of cluster in Kmeans and k=6 is the best nbr of cluster in agg so i try to use both
# k=8 is the best nbr of cluster in Kmeans and k=6 is the best nbr of cluster in agg so i try to use both
# k=8 is the best nbr of cluster in Kmeans and k=6 is the best nbr of cluster in agg so i try to use both
k_KM=8

# %%
# k_agg=6
# pred=[]
# pred_agg=pd.DataFrame(pred)
# agg_model = AgglomerativeClustering(n_clusters=k_agg, linkage='average')
# pred_agg["cluster"]=agg_model.fit_predict(princ_data)
# print(pred_agg.value_counts().sort_values(ascending=False))


# i can't use this model !!!!!!!!!!!!!!!!!!!!! cause of memory

# %%
genre_df = pd.read_csv("data_by_genres.csv")
print("Shape original :", genre_df.shape)

genre_df = genre_df[genre_df["genres"].str.strip() != "[]"].copy()
genre_df = genre_df.dropna(subset=["genres"]).reset_index(drop=True)
print("Shape après nettoyage :", genre_df.shape)
genre_df.head()
# Out:
# Shape original : (2973, 14)
# Shape après nettoyage : (2972, 14)
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1              a cappella      0.676557      0.538961  1.906285e+05
# 4     1                abstract      0.459210      0.516167  3.431965e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
# 4  0.442417          0.849667  0.118067 -15.472083     0.046517  127.885750
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# 1  0.221750   52.500000    5
# 2  0.975000   48.000000    7
# 3  0.448249   45.820071    7
# 4  0.307325   43.500000    1

# %%
scaler_genre = StandardScaler()
data_genre = scaler_genre.fit_transform(genre_df[fut_princ])
print(data_genre)
# Out:
# [[-2.48432022 -2.08926443 -3.91221519 ...  1.82784035 -1.92725355
#   -2.5007007 ]
#  [-1.57868449 -0.47132341 -1.18171535 ... -0.66906228 -1.34273793
#    0.07240734]
#  [ 1.16023582  1.09526817  0.24757383 ... -0.72320154  2.38955698
#    0.82565408]
#  ...
#  [ 1.405072    0.26124254  0.04098022 ... -1.11649318  1.64191432
#   -0.97634365]
#  [ 1.1182007  -1.65701643 -0.17583648 ... -0.14210683  1.22019541
#   -1.58813202]
#  [ 0.61206723  0.20547723  0.12188701 ...  0.6830829   1.56477877
#    0.42048007]]

# %%
km_genre = KMeans(n_clusters=8, random_state=42, n_init=10)
genre_df["cluster"] = km_genre.fit_predict(data_genre)

print("nbr des genres par cluster :")
print(genre_df["cluster"].value_counts().sort_index())
# Out:
# nbr des genres par cluster :
# cluster
# 0    588
# 1    780
# 2    363
# 3    254
# 4    653
# 5     67
# 6    246
# 7     21
# Name: count, dtype: int64

# %%
CLUSTER_NAME = {
    0:  "Electronic & Chill Instrumentals",
    1:  "Peaceful Acoustic & Classical",
    2:  "Feel-Good Dance & Pop",
    3:  "Heavy Punk & Metal",
    4:  "Hip-Hop & Dance Beats",
    5:  "Comedy & Spoken Audio",
    6:  "Relaxing Classical Instrumentals",
    7:  "Hard Rock & Heavy Metal"
}

genre_df["cluster_name"] = genre_df["cluster"].map(CLUSTER_NAME)

for c, name in CLUSTER_NAME.items():
    count = (genre_df["cluster"] == c).sum()
    sample_genres = genre_df[genre_df["cluster"] == c]["genres"].tolist()[:4]
    print(f"Cluster {c:2d} : {name:<40} nbr genre : {count:4d} genres | ex: {', '.join(sample_genres)}")
# Out:
# Cluster  0 : Electronic & Chill Instrumentals         nbr genre :  588 genres | ex: acid rock, action rock, adoracion, african percussion
# Cluster  1 : Peaceful Acoustic & Classical            nbr genre :  780 genres | ex: abstract beats, acoustic punk, afghan pop, african reggae
# Cluster  2 : Feel-Good Dance & Pop                    nbr genre :  363 genres | ex: 21st century classical, 432hz, acousmatic, african-american classical
# Cluster  3 : Heavy Punk & Metal                       nbr genre :  254 genres | ex: 8-bit, abstract, acid house, acid trance
# Cluster  4 : Hip-Hop & Dance Beats                    nbr genre :  653 genres | ex: a cappella, accordeon, accordion, acoustic blues
# Cluster  5 : Comedy & Spoken Audio                    nbr genre :   67 genres | ex: arabic hip hop, atmospheric post-metal, atmospheric sludge, australian underground hip hop
# Cluster  6 : Relaxing Classical Instrumentals         nbr genre :  246 genres | ex: abstract hip hop, afro dancehall, afro soul, afrofuturism
# Cluster  7 : Hard Rock & Heavy Metal                  nbr genre :   21 genres | ex: black comedy, clean comedy, comedy, deep comedy

# %%
profile = genre_df.groupby("cluster_name")[fut_princ + ["popularity"]].mean().round(3)
profile
# Out:
#                                   danceability  energy  loudness  speechiness  \
# cluster_name
# Comedy & Spoken Audio                    0.504   0.594   -10.642        0.093
# Electronic & Chill Instrumentals         0.457   0.793    -6.470        0.079
# Feel-Good Dance & Pop                    0.327   0.172   -21.252        0.051
# Hard Rock & Heavy Metal                  0.604   0.377   -16.903        0.763
# Heavy Punk & Metal                       0.551   0.679    -9.507        0.063
# Hip-Hop & Dance Beats                    0.526   0.377   -12.336        0.064
# Peaceful Acoustic & Classical            0.644   0.651    -8.234        0.066
# Relaxing Classical Instrumentals         0.719   0.671    -7.130        0.209
#
#                                   acousticness  instrumentalness  liveness  \
# cluster_name
# Comedy & Spoken Audio                    0.459             0.326     0.577
# Electronic & Chill Instrumentals         0.105             0.118     0.212
# Feel-Good Dance & Pop                    0.877             0.603     0.153
# Hard Rock & Heavy Metal                  0.723             0.025     0.387
# Heavy Punk & Metal                       0.172             0.617     0.183
# Hip-Hop & Dance Beats                    0.693             0.156     0.181
# Peaceful Acoustic & Classical            0.283             0.065     0.174
# Relaxing Classical Instrumentals         0.200             0.033     0.185
#
#                                   valence    tempo  popularity
# cluster_name
# Comedy & Spoken Audio               0.474  113.569      33.247
# Electronic & Chill Instrumentals    0.415  132.945      45.079
# Feel-Good Dance & Pop               0.229  103.703      31.259
# Hard Rock & Heavy Metal             0.457  102.264      13.306
# Heavy Punk & Metal                  0.407  121.644      38.163
# Hip-Hop & Dance Beats               0.505  114.356      31.342
# Peaceful Acoustic & Classical       0.668  119.417      45.618
# Relaxing Classical Instrumentals    0.576  119.675      51.044

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_result = tsne.fit_transform(data_genre)

genre_df["tsne_1"] = tsne_result[:, 0]
genre_df["tsne_2"] = tsne_result[:, 1]

# %%
fig_genre = px.scatter(
    genre_df,
    x="tsne_1",
    y="tsne_2",
    color="cluster_name",
    hover_name="genres",
    hover_data={
        "cluster_name":   True,
        "popularity":     ":.1f",
        "danceability":   ":.3f",
        "energy":         ":.3f",
        "valence":        ":.3f",
        "acousticness":   ":.3f",
        "tempo":          ":.1f",
        "tsne_1":         False,
        "tsne_2":         False,
    },
    title="<b>Clustering des Genres Musicaux using T-SNE with k=8</b>",
    labels={"color": "Groupe"},
    color_discrete_sequence=px.colors.qualitative.Set3,
    width=1000,
    height=700,
)
fig_genre.update_traces(marker=dict(size=7, line=dict(width=0.5, color="white")))
fig_genre.update_layout(
    title_font_size=16,
    legend_title_text="Groupe musical",
    plot_bgcolor="white",
    paper_bgcolor="white",
    legend=dict(font=dict(size=11)),
)
fig_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9dbd4b04-c007-40b0-800e-23d3e5c615bd" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dbd4b04-c007-40b0-800e-23d3e5c615bd")) {                    Plotly.newPlot(                        "9dbd4b04-c007-40b0-800e-23d3e5c615bd",                        [{"customdata":[["Feel-Good Dance & Pop",27.83333333333333,0.1628833333333333,0.0713166666666666,0.1037833333333333,0.9793333333333332,75.3365],["Feel-Good Dance & Pop",52.5,0.2993333333333333,0.4506783333333333,0.22175,0.49478,120.28566666666666],["Feel-Good Dance & Pop",9.342524154589372,0.4204582850241546,0.2385243417874396,0.3244473852657005,0.9170191062801932,104.07463265700486],["Feel-Good Dance & Pop",30.64944134078212,0.283975667287399,0.1421949224084419,0.2644644165114836,0.9255341402855372,132.72893202979515],["Feel-Good Dance & Pop",43.24113652812282,0.3350752947488824,0.2762974584117708,0.1914820761450744,0.6732743467076509,107.28752653132194],["Feel-Good Dance & Pop",44.58333333333333,0.2764166666666666,0.21773,0.1686683333333333,0.7447083333333333,95.92368333333334],["Feel-Good Dance & Pop",46.5,0.15565,0.02395,0.04755,0.987,69.16649999999998],["Feel-Good Dance & Pop",23.71227785372523,0.229740742481203,0.209583198051948,0.1959252093301435,0.895728896103896,103.75853251025288],["Feel-Good Dance & Pop",24.39556906216929,0.3553547222172736,0.0965707140494388,0.2466597114470225,0.9766781523472092,104.73920251395992],["Feel-Good Dance & Pop",30.58515625,0.3181496647509579,0.1110884352550287,0.2673089520474137,0.9383158147749042,99.85311179058913],["Feel-Good Dance & Pop",41.0,0.1715,0.06905,0.0923,0.995,168.6375],["Feel-Good Dance & Pop",8.804251166944681,0.3973823574849173,0.2668459794892684,0.4015047579500618,0.8906899671532347,117.09688837919882],["Feel-Good Dance & Pop",23.995722638899714,0.2672358330558825,0.1759945011458157,0.2127989448922158,0.8773235141712309,101.77994512400936],["Feel-Good Dance & Pop",22.87849462365591,0.3490272401433692,0.3724985663082437,0.3767143369175625,0.6602178279569892,120.15716272401431],["Feel-Good Dance & Pop",16.46153846153846,0.3173994755244756,0.1434371503496503,0.2346690559440559,0.9545708041958042,115.72976311188808],["Feel-Good Dance & Pop",21.21212121212121,0.2392565656565657,0.1345641414141414,0.2706393939393939,0.933919191919192,86.86002525252525],["Feel-Good Dance & Pop",36.16666666666667,0.4878333333333333,0.1718333333333333,0.386,0.9076666666666668,118.93916666666668],["Feel-Good Dance & Pop",37.0,0.1369999999999999,0.128175,0.0445,0.993,87.93799999999996],["Feel-Good Dance & Pop",18.357705406555983,0.3407063005534269,0.1111799063431247,0.1979045232013623,0.9875466155810982,114.95943965517242],["Feel-Good Dance & Pop",63.0,0.1852222222222222,0.3083333333333333,0.0270111111111111,0.4809677777777777,80.81955555555554],["Feel-Good Dance & Pop",51.53571428571429,0.2700989795918367,0.118075,0.1361602040816326,0.8895132653061226,93.49492346938776],["Feel-Good Dance & Pop",58.0,0.301,0.0089,0.0897,0.987,127.536],["Feel-Good Dance & Pop",15.0,0.291,0.0218,0.291,0.993,136.83700000000002],["Feel-Good Dance & Pop",26.0,0.3569999999999999,0.171075,0.1565499999999999,0.359525,104.83375],["Feel-Good Dance & Pop",39.0,0.113,0.0732,0.0379,0.969,174.59900000000005],["Feel-Good Dance & Pop",12.10648148148148,0.2245555555555555,0.2596279166666667,0.1626189814814815,0.9503240740740742,98.97342129629632],["Feel-Good Dance & Pop",22.017857142857142,0.3463606601731602,0.1011578354978355,0.2386801677489177,0.9880094696969698,116.82928111471858],["Feel-Good Dance & Pop",19.933588252290548,0.2380837077892421,0.1354660233691245,0.1920575663628144,0.9533671100951636,121.79752735951496],["Feel-Good Dance & Pop",4.323809523809524,0.36567619047 ...

# %%
data_songs = scaler.fit_transform(data[fut_princ])
print(f"Données chansons standardisées : {data_songs.shape}")
# Out:
# Données chansons standardisées : (89740, 9)

# %%
km_songs = KMeans(n_clusters=25, random_state=42, n_init=10)
data = data.copy()
data["cluster"] = km_songs.fit_predict(data_songs)

print("Distribution des chansons par cluster :")
print(data["cluster"].value_counts().sort_index())
# Out:
# Distribution des chansons par cluster :
# cluster
# 0     2584
# 1     6417
# 2     7797
# 3     4287
# 4     1964
# 5     4930
# 6      905
# 7     4708
# 8     4362
# 9     2395
# 10    2986
# 11    5908
# 12    2153
# 13    2307
# 14    3265
# 15    4389
# 16    2972
# 17    3422
# 18    2965
# 19    2628
# 20    3734
# 21    4812
# 22    2762
# 23    4500
# 24     588
# Name: count, dtype: int64

# %%
pca = PCA(n_components=2, random_state=42)
pca_result = pca.fit_transform(data_songs)

data["pca_1"] = pca_result[:, 0]
data["pca_2"] = pca_result[:, 1]

print(f"Variance expliquée par les 2 composantes PCA : {pca.explained_variance_ratio_.sum():.2%}")

sample_viz = data.sample(8000, random_state=42)

fig_songs = px.scatter(
    sample_viz,
    x="pca_1",
    y="pca_2",
    color=sample_viz["cluster"].astype(str),
    hover_name="track_name",
    hover_data={
        "artists":      True,
        "track_genre":  True,
        "popularity":   True,
        "pca_1":        False,
        "pca_2":        False,
        "cluster":      False,
    },
    title="<b>Clustering des Chansons — PCA k=25, échantillon of  8000 ligne</b>",
    labels={"color": "Cluster"},
    color_discrete_sequence=px.colors.qualitative.Alphabet,
    width=1000,
    height=700,
    opacity=0.7,
)
fig_songs.update_traces(marker=dict(size=5))
fig_songs.update_layout(
    title_font_size=16,
    legend_title_text="Cluster",
    plot_bgcolor="white",
    paper_bgcolor="white",
)
fig_songs.show()
# Out:
# Variance expliquée par les 2 composantes PCA : 47.99%
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3ae4a9c0-fdf4-4605-9bba-447596b8bb72" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ae4a9c0-fdf4-4605-9bba-447596b8bb72")) {                    Plotly.newPlot(                        "3ae4a9c0-fdf4-4605-9bba-447596b8bb72",                        [{"customdata":[["Feid","latin",0,1],["Electric Youth","synth-pop",41,1],["Dimitri Vegas & Like Mike;DVBBS;Roy Woods","progressive-house",48,1],["Yves V;Ilkay Sencan;Emie","progressive-house",65,1],["All Ok","k-pop",50,1],["Rella;Conor Gardiner","emo",59,1],["Mark D. Pencil","kids",14,1],["Peggy Lee","soul",0,1],["ThirumaLi","malay",28,1],["Salsangroove","salsa",35,1],["Totally Enormous Extinct Dinosaurs","disco",55,1],["MC Kaique da VP","funk",63,1],["Fiona Sit","cantopop",40,1],["Linkin Park","grunge",35,1],["Viva La Panda;Next to Neon","deep-house",40,1],["LIT killah","latino",43,1],["Mavado;Di Genius;Stacious","j-dance",51,1],["Mainstreet;Azevedo;PL Quest;Orochi;Shenlong;Kizzy","funk",43,1],["Creep Hyp","j-pop",39,1],["shy martin","swedish",52,1],["Bad Bunny","latin",94,1],["Groundation","dub",27,1],["DVBBS;24kGoldn;blackbear","electronic",60,1],["David Puentez","progressive-house",63,1],["Leon Lai","cantopop",22,1],["Nicola Conte;Stefania Dipierro","trip-hop",19,1],["Jaylon Ashaun","chill",54,1],["CHVRCHES","synth-pop",49,1],["Kygo;Dean Lewis","edm",73,1],["Marshmello;Demi Lovato;Lost Stories","edm",47,1],["Kinderen voor Kinderen","children",30,1],["Gareth Emery","trance",48,1],["Jakob Hellman","swedish",35,1],["Ed Sheeran;Lil Baby","pop",0,1],["OAFF;Savera;Lothika;Kausar Munir","indian",73,1],["Ketama126","emo",37,1],["Promoting Sounds;Powfu;Ouse","emo",66,1],["Bee Gees;SG Lewis","disco",69,1],["BrxkenBxy","sad",55,1],["Bad Bunny","latino",79,1],["Marshmello;NITTI;Megan Thee Stallion","progressive-house",53,1],["Cali Y El Dandee;Sebastian Yatra","electro",0,1],["D.O.D;RIELL","deep-house",53,1],["Jason Mraz","acoustic",53,1],["Morbo y Mambo;Andres Nusser","afrobeat",22,1],["Kölsch","minimal-techno",52,1],["Anitta;Missy Elliott","funk",1,1],["Hayley Kiyoko","indie-pop",0,1],["Skinny Puppy","industrial",21,1],["Enigma","new-age",40,1],["Alok;Bastille","electro",0,1],["Duki;KHEA","latino",82,1],["Ekin Cheng","cantopop",24,1],["Gerson Rufino","gospel",39,1],["Hardwell;Henry Fong;Mr. Vegas","progressive-house",37,1],["Ricky Montgomery","indie-pop",79,1],["Jack Harlow","hip-hop",0,1],["JEON SOMI","k-pop",59,1],["Kevin Martes 13;Pablo Chill-E","latino",49,1],["Franco Wildlife","dancehall",26,1],["Lonely Night","french",56,1],["Karthik","pop-film",64,1],["Romanthony;Mia Dora","chicago-house",31,1],["Robert Owens;Josh Butler","chicago-house",10,1],["Tenth Avenue North","world-music",44,1],["Lil Pump","emo",55,1],["Julianno Sosa","latino",42,1],["ZONE","j-idol",23,1],["Neha Kakkar;Arjun Kanungo","pop-film",60,1],["MEDUZA;Becky Hill;Goodboys","dance",78,1],["chloe moriondo","indie-pop",0,1],["Zac Samuel;MØØNE","deep-house",1,1],["for KING & COUNTRY","world-music",55,1],["Linn da Quebrada;BADSISTA","club",29,1],["Tiësto;SWACQ","trance",42,1],["menores atos","hardcore",32,1],["MC L da Vinte;MC Gury","funk",69,1],["Stupeflip;Tanguy P","french",33,1],["Pritam;Sukhbir;Soham Chakrabarthy;Sameer","indian",47,1],["Martin Garrix","progressive-house",48,1],["DrefQuila","latino",41,1],["Şanışer;Sokrat St","turkish",40,1],["Marie-Flore","french",33,1],["Aries","sad",60,1],["Zanger Kafke","hardstyle",30,1],["Miso","chill",55,1],["Maneva","brazil",45,1],["C-Ro;Don Bnnr;Lazy Panda","minimal-techno",20,1],["MC Guto VGS;MC Pê Original;MC Neguinho R;DJ Andrômeda","funk",0,1],["Blake Rules;Netherfriends","kids",7,1],["Surgeon","detroit-techno",7,1],["DOLLA","malay",0,1],["Paulo Londra;Ed Sheeran", ...

# %%
song_cluster_profile = data.groupby("cluster")[fut_princ].mean().round(3)
song_cluster_profile
# Out:
#          danceability  energy  loudness  speechiness  acousticness  \
# cluster
# 0               0.616   0.309   -14.512        0.066         0.778
# 1               0.722   0.652    -7.002        0.066         0.138
# 2               0.726   0.774    -5.959        0.065         0.120
# 3               0.490   0.504    -8.160        0.044         0.452
# 4               0.287   0.062   -28.675        0.049         0.934
# 5               0.539   0.848    -5.098        0.068         0.080
# 6               0.561   0.700   -11.274        0.887         0.784
# 7               0.624   0.319   -11.831        0.053         0.782
# 8               0.487   0.583    -7.542        0.044         0.196
# 9               0.550   0.621    -8.561        0.074         0.564
# 10              0.370   0.215   -14.394        0.045         0.863
# 11              0.467   0.878    -4.922        0.078         0.033
# 12              0.658   0.733    -6.086        0.319         0.190
# 13              0.271   0.208   -17.948        0.045         0.823
# 14              0.427   0.335   -10.926        0.044         0.752
# 15              0.391   0.893    -4.561        0.099         0.034
# 16              0.340   0.884    -6.355        0.095         0.029
# 17              0.612   0.628    -7.704        0.062         0.556
# 18              0.727   0.629    -7.715        0.326         0.302
# 19              0.475   0.852    -5.670        0.096         0.088
# 20              0.673   0.706    -9.108        0.061         0.073
# 21              0.695   0.569    -8.352        0.057         0.553
# 22              0.691   0.756    -8.511        0.062         0.103
# 23              0.655   0.832    -5.228        0.071         0.121
# 24              0.192   0.507   -19.632        0.057         0.505
#
#          instrumentalness  liveness  valence    tempo
# cluster
# 0                   0.838     0.140    0.381  115.938
# 1                   0.027     0.140    0.398  114.001
# 2                   0.016     0.116    0.784  114.602
# 3                   0.022     0.161    0.331   89.946
# 4                   0.835     0.123    0.156   96.266
# 5                   0.024     0.170    0.696  158.766
# 6                   0.004     0.725    0.429   99.306
# 7                   0.018     0.155    0.483  112.315
# 8                   0.021     0.154    0.278  142.235
# 9                   0.021     0.784    0.596  115.126
# 10                  0.034     0.168    0.226   89.214
# 11                  0.037     0.199    0.341  105.088
# 12                  0.029     0.193    0.534  160.781
# 13                  0.860     0.134    0.121  105.295
# 14                  0.023     0.151    0.292  150.349
# 15                  0.047     0.214    0.302  163.705
# 16                  0.778     0.235    0.212  131.764
# 17                  0.016     0.181    0.766  155.443
# 18                  0.017     0.175    0.583  100.020
# 19                  0.090     0.767    0.394  135.055
# 20                  0.792     0.146    0.211  126.525
# 21                  0.016     0.161    0.771  102.450
# 22                  0.783     0.148    0.694  125.402
# 23                  0.019     0.390    0.701  119.033
# 24                  0.719     0.741    0.065   82.400

# %%
for c in sorted(data["cluster"].unique())[:10]:
    top_g = data[data["cluster"] == c]["track_genre"].value_counts().head(3)
    print(f"Cluster {c} — top genres : {', '.join(top_g.index.tolist())}")
# Out:
# Cluster 0 — top genres : study, guitar, classical
# Cluster 1 — top genres : deep-house, dance, edm
# Cluster 2 — top genres : disco, dance, latin
# Cluster 3 — top genres : mandopop, pop-film, cantopop
# Cluster 4 — top genres : sleep, piano, ambient
# Cluster 5 — top genres : j-idol, power-pop, forro
# Cluster 6 — top genres : comedy, show-tunes, kids
# Cluster 7 — top genres : tango, honky-tonk, acoustic
# Cluster 8 — top genres : world-music, mandopop, dub
# Cluster 9 — top genres : pagode, samba, sertanejo

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(princ_data)

data["pca_1"] = X_pca[:, 0]
data["pca_2"] = X_pca[:, 1]
print(data.columns)
plt.figure(figsize=(10,7))
sns.scatterplot(data=data, x="pca_1", y="pca_2", hue="cluster",
                 palette="tab10", s=15, alpha=0.6)
plt.title(f"Visualisation des clusters k=25")
plt.show()

print(f"Variance expliquée par les 2 composantes : {pca.explained_variance_ratio_.sum():.2%}")
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'cluster', 'pca_1',
#        'pca_2'],
#       dtype='object')
# Variance expliquée par les 2 composantes : 47.99%

# %%
for claster in sorted(data["cluster"].unique()):
    top_genres_cluster = data[data["cluster"] == claster]["track_genre"].value_counts().head(5)
    print(f"\nCluster {claster} — have as genres :")
    print(top_genres_cluster)
# Out:
# Cluster 0 — have as genres :
# track_genre
# study        534
# guitar       314
# classical    142
# idm          136
# chill        133
# Name: count, dtype: int64
#
# Cluster 1 — have as genres :
# track_genre
# deep-house    333
# dance         273
# edm           223
# hip-hop       195
# turkish       170
# Name: count, dtype: int64
#
# Cluster 2 — have as genres :
# track_genre
# disco        321
# dance        248
# latin        248
# kids         238
# dancehall    233
# Name: count, dtype: int64
#
# Cluster 3 — have as genres :
# track_genre
# mandopop    154
# pop-film    137
# cantopop    134
# indian      133
# malay       108
# Name: count, dtype: int64
#
# Cluster 4 — have as genres :
# track_genre
# sleep        402
# piano        297
# ambient      297
# classical    270
# new-age      156
# Name: count, dtype: int64
#
# Cluster 5 — have as genres :
# track_genre
# j-idol       260
# power-pop    209
# forro        175
# punk-rock    157
# ska          153
# Name: count, dtype: int64
#
# Cluster 6 — have as genres :
# track_genre
# comedy        795
# show-tunes     13
# kids           12
# children       12
# jazz            7
# Name: count, dtype: int64
#
# Cluster 7 — have as genres :
# track_genre
# tango         382
# honky-tonk    376
# acoustic      218
# cantopop      208
# romance       186
# Name: count, dtype: int64
#
# Cluster 8 — have as genres :
# track_genre
# world-music    243
# mandopop       187
# dub            167
# gospel         156
# cantopop       149
# Name: count, dtype: int64
#
# Cluster 9 — have as genres :
# track_genre
# pagode       381
# samba        209
# sertanejo    189
# mpb          165
# tango         85
# Name: count, dtype: int64
#
# Cluster 10 — have as genres :
# track_genre
# opera         357
# romance       350
# show-tunes    191
# disney        144
# jazz          142
# Name: count, dtype: int64
#
# Cluster 11 — have as genres :
# track_genre
# death-metal    371
# heavy-metal    366
# metalcore      308
# grunge         244
# grindcore      217
# Name: count, dtype: int64
#
# Cluster 12 — have as genres :
# track_genre
# j-dance      112
# hardstyle     93
# dancehall     90
# happy         82
# hip-hop       76
# Name: count, dtype: int64
#
# Cluster 13 — have as genres :
# track_genre
# new-age      445
# iranian      281
# ambient      261
# classical    172
# disney       168
# Name: count, dtype: int64
#
# Cluster 14 — have as genres :
# track_genre
# cantopop    195
# mandopop    157
# acoustic    153
# romance     153
# opera       143
# Name: count, dtype: int64
#
# Cluster 15 — have as genres :
# track_genre
# hardstyle        343
# happy            274
# drum-and-bass    253
# metalcore        231
# grunge           195
# Name: count, dtype: int64
#
# Cluster 16 — have as genres :
# track_genre
# grindcore        600
# black-metal      450
# death-metal      242
# iranian          208
# drum-and-bass    195
# Name: count, dtype: int64
#
# Cluster 17 — have as genres :
# track_genre
# forro         287
# salsa         203
# pagode        188
# bluegrass     156
# honky-tonk    132
# Name: count, dtype: int64
#
# Cluster 18 — have as genres :
# track_genre
# dancehall    277
# j-dance      255
# kids         170
# funk         165
# hardcore     160
# Name: count, dtype: int64
#
# Cluster 19 — have as genres :
# track_genre
# heavy-metal    130
# happy          113
# sertanejo      111
# world-music    110
# hardstyle       90
# Name: count, dtype: int64
#
# Cluster 20 — have as genres :
# track_genre
# minimal-techno    601
# detroit-techno    357
# trance            220
# idm               217
# techno            213
# Name: count, dtype: int64
#
# Cluster 21 — have as genres :
# track_genre
# salsa          340
# children       246
# rock-n-roll    179
# bluegrass      158
# honky-tonk     143
# Name: count, dtype: int64
#
# Cluster 22 — have as genres :
# track_genre
# chicago-house     369
# detroit-techno    334
# afrobeat          214
# breakbeat         172
# study             160
# Name: count, dtype: int64
#
# Cluster 23 — have as genres :
# track_genre
# party        274
# j-idol       154
# disco        153
# forro        131
# sertanejo    114
# Name: count, dtype: int64
#
# Cluster 24 — have as genres :
# track_genre
# sleep          324
# new-age         77
# iranian         25
# opera           23
# world-music     20
# Name: count, dtype: int64

# %%
print(data.columns)
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'cluster', 'pca_1',
#        'pca_2'],
#       dtype='object')

# %%
# DBSCAN
# Hierarchical clustering
